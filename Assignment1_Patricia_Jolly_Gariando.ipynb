# %% [markdown]
# Part 1: Cover Page and Table of Contents (see word doc)

# %% [markdown]
# Part 2: Choose a Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airline = pd.read_csv('Invistico_Airline.csv')

# %%
airline.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %% [markdown]
# Part 3: Ask a Question

# %% [markdown]
# Will a future customer be satisfied flying Invistico Airline? (see word doc)

# %% [markdown]
# Part 4: Clean Your Data

# %%
#Dropped 
airline.drop('Class', axis=1, inplace=True)
airline.drop('Flight Distance', axis=1, inplace=True)
airline.drop('Departure/Arrival time convenient', axis=1, inplace=True)
airline.drop('Gate location', axis=1, inplace=True)
airline.drop('Online support', axis=1, inplace=True)
airline.drop('Ease of Online booking', axis=1, inplace=True)
airline.drop('Arrival Delay in Minutes', axis=1, inplace=True)

#Replaced
airline.replace('Male', 0, inplace=True)
airline.replace('Female', 1, inplace=True)
airline.replace('satisfied', 0, inplace=True)
airline.replace('dissatisfied', 1, inplace=True)
airline.replace('Loyal Customer', 0, inplace=True)
airline.replace('disloyal Customer', 1, inplace=True)
airline.replace('Personal Travel', 0, inplace=True)
airline.replace('Business travel', 1, inplace=True)

#Dropped NaN rows 
airline.dropna(axis=0, inplace=True)

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   satisfaction                129880 non-null  int64
#  1   Gender                      129880 non-null  int64
#  2   Customer Type               129880 non-null  int64
#  3   Age                         129880 non-null  int64
#  4   Type of Travel              129880 non-null  int64
#  5   Seat comfort                129880 non-null  int64
#  6   Food and drink              129880 non-null  int64
#  7   Inflight wifi service       129880 non-null  int64
#  8   Inflight entertainment      129880 non-null  int64
#  9   On-board service            129880 non-null  int64
#  10  Leg room service            129880 non-null  int64
#  11  Baggage handling            129880 non-null  int64
#  12  Checkin service             129880 non-null  int64
# ...

# %% [markdown]
# Part 5: Graph Your Data

# %% [markdown]
# **reminder to use sns.pairplot(airline) to give you an idea of what the graphs might look like

# %%
sns.lineplot(data=airline, x='Age', y='satisfaction').set_title('How satisfied are you flying with Invistico Airline?')
# Out:
# c:\Users\garia\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\garia\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'How satisfied are you flying with Invistico Airline?')

# %%
sns.violinplot(data=airline, x='Customer Type', y='On-board service', palette='PuBuGn').set_title('How well are loyal passengers treated vs disloyal passengers?')
# Out:
# Text(0.5, 1.0, 'How well are loyal passengers treated vs disloyal passengers?')

# %%
sns.barplot(data=airline, x='Gender', y='satisfaction', palette='Accent').set_title('Which gender is more satisfied with the airlines?')
# Out:
# Text(0.5, 1.0, 'Which gender is more satisfied with the airlines?')

# %%
sns.boxplot(data=airline, x='Leg room service', y='Seat comfort', palette='YlGnBu').set_title('How comfortable are the seats?')
# Out:
# Text(0.5, 1.0, 'How comfortable are the seats?')

# %%
sns.boxenplot(data=airline, x='Inflight entertainment', y='Inflight wifi service', palette='RdYlGn').set_title('Are the inflight services good?')
# Out:
# c:\Users\garia\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\garia\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\garia\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Part 6: Train and Test Your Algorithm

# %%
# We need to split our data into x and y. We use X to predict y.
X, y = airline.drop('satisfaction', axis=1), airline['satisfaction'].values

# %%
# Split the data into a training set and a testing set 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=87)

# %%
# Train our algorithm 
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=200000)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200000)

# %% [markdown]
# Part 7: Evaluate Your Model

# %%
# Score our model, how accurate is our model?
logmodel.score(X_test, y_test)
# Out:
# 0.8289703315881326

# %% [markdown]
# Part 8: Answer Your Question and Conclusion

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, logmodel.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84     21219
#            1       0.81      0.81      0.81     17745
#
#     accuracy                           0.83     38964
#    macro avg       0.83      0.83      0.83     38964
# weighted avg       0.83      0.83      0.83     38964

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      129880 non-null  int64
#  1   Customer Type               129880 non-null  int64
#  2   Age                         129880 non-null  int64
#  3   Type of Travel              129880 non-null  int64
#  4   Seat comfort                129880 non-null  int64
#  5   Food and drink              129880 non-null  int64
#  6   Inflight wifi service       129880 non-null  int64
#  7   Inflight entertainment      129880 non-null  int64
#  8   On-board service            129880 non-null  int64
#  9   Leg room service            129880 non-null  int64
#  10  Baggage handling            129880 non-null  int64
#  11  Checkin service             129880 non-null  int64
#  12  Cleanliness                 129880 non-null  int64
# ...

# %%
passenger = {               
    'Gender':[1],                      #0 for male, 1 for female
    'Customer Type':[1],               #0 for Loyal, 1 for Disloyal
    'Age':[26], 
    'Type of Travel':[0],              #0 for Personal, 1 for Business 
    'Seat comfort':[3],                #rating of 1-5 
    'Food and drink':[2],    
    'Inflight wifi service':[0],      
    'Inflight entertainment':[4],    
    'On-board service':[4],
    'Leg room service':[3],
    'Baggage handling':[5],
    'Checkin service':[4],
    'Cleanliness':[2],      
    'Online boarding':[3],
    'Departure Delay in Minutes':[0],
}
dateframe = pd.DataFrame(passenger)
print(logmodel.predict(dateframe))
# Out:
# [1]

# %% [markdown]
# 0 - Satisfied <br>
# 1 - Dissastisfied
